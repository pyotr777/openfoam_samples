# %%
# %matplotlib inline
import numpy as np
from vtk.util.numpy_support import vtk_to_numpy
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import vtk
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D

# %%
def getData_vtk(filename):
    # load a vtk file as input
    reader = vtk.vtkUnstructuredGridReader()
    reader.SetFileName(filename)
    reader.Update()
    print reader.GetOutput().GetPoints()
    # Get the coordinates of nodes in the mesh
    nodes_vtk_array= reader.GetOutput().GetPoints().GetData()  
    pressure_vtk_array = reader.GetOutput().GetPointData().GetArray(0)
    speed_vtk_array = reader.GetOutput().GetPointData().GetArray(1)
    nodes = vtk_to_numpy(nodes_vtk_array)
    p = vtk_to_numpy(pressure_vtk_array)
    U  = vtk_to_numpy(speed_vtk_array)
    return nodes, p, U

# %%
def extractFlatData(nodes, p, U):
    merged = np.empty([len(nodes),6])
    merged[:,0] = p
    merged[:,1:3] = U[:,:2]
    merged[:,3:] = nodes
    # Merged z0 and z1 arrays should be same because of 
    # the model symmetry along z-axis
    merged_z0 = merged[np.where(merged[:,5] == 0)]
    merged_z1 = merged[np.where(merged[:,5] != 0)]
    # Extract nodes, p and U arrays from z0 array
    p = merged_z0[:,0]
    U = merged_z0[:,1:3]
    nodes = merged_z0[:,3:5]
    return nodes, p, U

def plot2D(nodes, a, vmin, vmax):     
    # 2d plotting
    fig = plt.figure(figsize=(8,6))
    color_map = plt.cm.get_cmap('viridis')
    axes = plt.gca()
    #axes.set_xlim([-.1,2.1])
    #axes.set_ylim([-.01,0.11])
    #plt.axis('off')
    sc = plt.scatter(nodes[:,0],nodes[:,1],
                     s=320,
#                     color=cmap(a / a_max),
                     c = a,
                     cmap = color_map,
                     vmin = vmin,
                     vmax = vmax,
                     linewidth=0, 
                     marker="s")
    plt.colorbar(sc)
    fig.tight_layout()
    
def plotVector(X, Y, UN, VN, U, vmin, vmax, filename=""):
    plot1 = plt.figure(figsize=(14,10))
    plt.quiver(X, Y, UN, VN,        # data
               U,                   # colour the arrows based on this array
               cmap=plt.cm.seismic,     # colour map
               norm=mpl.colors.Normalize(vmin=vmin,vmax=vmax), # Colour range fix
               headlength=4,
               width=0.007,
               scale_units='xy', 
               scale=9,
               linewidths=1,
               edgecolors='k'
               )

    plt.colorbar()                  # adds the colour bar
    plt.xlabel('X')
    plt.ylabel('Y')
    plt.title('Velocity vector')
    if (filename != ""):
        plot1.tight_layout()
        plt.savefig(filename,bbox_inches='tight')
    else:
        plt.show(plot1)                 # display the plot
    plt.close(plot1)

# %%
vtkdir = "cavity.out/VTK"
import os
files = os.listdir(vtkdir)
for f in files[:12]:
    print(f)
# Out:
# cavity_0.vtk
# cavity_100.vtk
# cavity_150.vtk
# cavity_200.vtk
# cavity_250.vtk
# cavity_300.vtk
# cavity_350.vtk
# cavity_400.vtk
# cavity_450.vtk
# cavity_50.vtk
# cavity_500.vtk
# fixedWalls

# %%
vtkdir = "cavity.out/VTK"
import os

vmin = 0
vmax = 1

imdir = "export"
try:
    os.stat(imdir)
except:
    os.mkdir(imdir)
    
n = 0
for i in range(0,501,50):
    print i
    filename = vtkdir+"/cavity_"+str(i) + ".vtk"
    im_filename = imdir + "/" + "cavity" + str(n).zfill(4) + ".png"
    print "From {} to {}".format(filename, im_filename)
    n += 1

    nodes, p , U   = getData_vtk(filename)
    nodes_half, p_half, U_half = extractFlatData(nodes, p, U)
    Un_half = np.sqrt(U_half[:,0]**2 + U_half[:,1]**2) #Randomisation:  + np.random.rand(U_half.shape[0])
    print(np.amin(Un_half),np.amax(Un_half))

    plotVector(nodes_half[:,0], nodes_half[:,1], U_half[:,0], U_half[:,1], 
               Un_half, vmin, vmax, filename = im_filename)
# Out:
# 0
# From cavity.out/VTK/cavity_0.vtk to export/cavity0000.png
# vtkPoints (0x29417a0)
#   Debug: Off
#   Modified Time: 1540
#   Reference Count: 2
#   Registered Events: (none)
#   Data: 0x27185f0
#   Data Array Name: Points
#   Number Of Points: 882
#   Bounds:
#     Xmin,Xmax: (-1.01414e+27, 7.71994e+35)
#     Ymin,Ymax: (-1.01414e+27, 7.71994e+35)
#     Zmin,Zmax: (0, 2.0717e-32)
#
#
# (0.0, 4.6006029882248069e-41)
# 50
# From cavity.out/VTK/cavity_50.vtk to export/cavity0001.png
# vtkPoints (0x2def5a0)
#   Debug: Off
#   Modified Time: 1749
#   Reference Count: 2
#   Registered Events: (none)
#   Data: 0x2df5080
#   Data Array Name: Points
#   Number Of Points: 882
#   Bounds:
#     Xmin,Xmax: (-1.01414e+27, 7.71994e+35)
#     Ymin,Ymax: (-1.01414e+27, 7.71994e+35)
#     Zmin,Zmax: (0, 2.0717e-32)
#
#
# (nan, nan)
# 100
# From cavity.out/VTK/cavity_100.vtk to export/cavity0002.png
# vtkPoints (0x29d10c0)
#   Debug: Off
#   Modified Time: 1958
#   Reference Count: 2
#   Registered Events: (none)
#   Data: 0x3c8d290
#   Data Array Name: Points
#   Number Of Points: 882
#   Bounds:
#     Xmin,Xmax: (-1.01414e+27, 7.71994e+35)
#     Ymin,Ymax: (-1.01414e+27, 7.71994e+35)
#     Zmin,Zmax: (0, 2.0717e-32)
#
#
# (nan, nan)
# 150
# From cavity.out/VTK/cavity_150.vtk to export/cavity0003.png
# vtkPoints (0x27e2310)
#   Debug: Off
#   Modified Time: 2167
#   Reference Count: 2
#   Registered Events: (none)
#   Data: 0x2826420
#   Data Array Name: Points
#   Number Of Points: 882
#   Bounds:
#     Xmin,Xmax: (-1.01414e+27, 7.71994e+35)
#     Ymin,Ymax: (-1.01414e+27, 7.71994e+35)
#     Zmin,Zmax: (0, 2.0717e-32)
#
#
# (nan, nan)
# 200
# From cavity.out/VTK/cavity_200.vtk to export/cavity0004.png
# vtkPoints (0x295f850)
#   Debug: Off
#   Modified Time: 2376
#   Reference Count: 2
#   Registered Events: (none)
#   Data: 0x27812e0
#   Data Array Name: Points
#   Number Of Points: 882
#   Bounds:
#     Xmin,Xmax: (-1.01414e+27, 7.71994e+35)
#     Ymin,Ymax: (-1.01414e+27, 7.71994e+35)
#     Zmin,Zmax: (0, 2.0717e-32)
#
#
# (nan, nan)
# 250
# From cavity.out/VTK/cavity_250.vtk to export/cavity0005.png
# vtkPoints (0x35a12f0)
#   Debug: Off
#   Modified Time: 2585
#   Reference Count: 2
#   Registered Events: (none)
#   Data: 0x3009e60
#   Data Array Name: Points
#   Number Of Points: 882
#   Bounds:
#     Xmin,Xmax: (-1.01414e+27, 7.71994e+35)
#     Ymin,Ymax: (-1.01414e+27, 7.71994e+35)
#     Zmin,Zmax: (0, 2.0717e-32)
#
#
# (nan, nan)
# 300
# From cavity.out/VTK/cavity_300.vtk to export/cavity0006.png
# vtkPoints (0x2aab3f0)
#   Debug: Off
#   Modified Time: 2794
#   Reference Count: 2
#   Registered Events: (none)
#   Data: 0x311cf90
#   Data Array Name: Points
#   Number Of Points: 882
#   Bounds:
#     Xmin,Xmax: (-1.01414e+27, 7.71994e+35)
#     Ymin,Ymax: (-1.01414e+27, 7.71994e+35)
#     Zmin,Zmax: (0, 2.0717e-32)
#
#
# (nan, nan)
# 350
# From cavity.out/VTK/cavity_350.vtk to export/cavity0007.png
# vtkPoints (0x35ddd40)
#   Debug: Off
#   Modified Time: 3003
#   Reference Count: 2
#   Registered Events: (none)
#   Data: 0x3b122e0
#   Data Array Name: Points
#   Number Of Points: 882
#   Bounds:
#     Xmin,Xmax: (-1.01414e+27, 7.71994e+35)
#     Ymin,Ymax: (-1.01414e+27, 7.71994e+35)
#     Zmin,Zmax: (0, 2.0717e-32)
#
#
# (0.0, 2.5009083184915467e+38)
# 400
# From cavity.out/VTK/cavity_400.vtk to export/cavity0008.png
# vtkPoints (0x3105b30)
#   Debug: Off
#   Modified Time: 3212
#   Reference Count: 2
#   Registered Events: (none)
#   Data: 0x53c6ba0
#   Data Array Name: Points
#   Number Of Points: 882
#   Bounds:
#     Xmin,Xmax: (-1.01414e+27, 7.71994e+35)
#     Ymin,Ymax: (-1.01414e+27, 7.71994e+35)
#     Zmin,Zmax: (0, 2.0717e-32)
#
#
# (nan, nan)
# 450
# From cavity.out/VTK/cavity_450.vtk to export/cavity0009.png
# vtkPoints (0x33e6d50)
#   Debug: Off
#   Modified Time: 3421
#   Reference Count: 2
#   Registered Events: (none)
#   Data: 0x4cb1820
#   Data Array Name: Points
#   Number Of Points: 882
#   Bounds:
#     Xmin,Xmax: (-1.01414e+27, 7.71994e+35)
#     Ymin,Ymax: (-1.01414e+27, 7.71994e+35)
#     Zmin,Zmax: (0, 2.0717e-32)
#
#
# (nan, nan)
# 500
# From cavity.out/VTK/cavity_500.vtk to export/cavity0010.png
# vtkPoints (0x4d4c630)
#   Debug: Off
#   Modified Time: 3630
#   Reference Count: 2
#   Registered Events: (none)
#   Data: 0x52570d0
#   Data Array Name: Points
#   Number Of Points: 882
#   Bounds:
#     Xmin,Xmax: (-1.01414e+27, 7.71994e+35)
#     Ymin,Ymax: (-1.01414e+27, 7.71994e+35)
#     Zmin,Zmax: (0, 2.0717e-32)
#
#
# (nan, nan)
